# %%
from isolation import Board
from game_agent import CustomPlayer

player1 = CustomPlayer()
player2 = CustomPlayer()
board = Board(player1, player2)
player1.minimax(board, 3)
# Out:
# == current palyer: <game_agent.CustomPlayer object at 0x1068fb5f8>
# max: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fba20>
# min: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fb5f8>
# max: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fba20>
# no more children!!!
# - max: b_v = -2.0
# max: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fba20>
# no more children!!!
# - max: b_v = -2.0
# - min: b_v = -2.0
# min: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fb5f8>
# max: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fba20>
# no more children!!!
# - max: b_v = -1.0
# max: going deeper..
# == current palyer: <game_agent.CustomPlayer object at 0x1068fba20>
# no more children!!!
# - max: b_v = -1.0
# - min: b_v = -2.0
# min: going deeper..
# ...
